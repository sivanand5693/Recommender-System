# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading data file
ratings = pd.read_csv('C:\\Users\\sivan\\Documents\\GIT Stuff\\Recommender-System\\Collaborative Filtering\\files\\Ratings.csv')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
#focusing on explicit ratings ONLY
ratings = ratings[ratings['Book-Rating']!=0]

# %%
print(ratings.shape)

print(len(ratings['User-ID'].unique())) #Unique Users

print(len(ratings['ISBN'].unique())) #Unique Books
# Out:
# (433671, 3)
# 77805
# 185973

# %%
#Plot of Ratings
plt.hist(ratings['Book-Rating'])
# Out:
# (array([  1770.,   2759.,   5996.,   8904.,  50974.,  36924.,  76457.,
#         103736.,  67541.,  78610.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 10 Patch objects>)

# %%
#As you can see, most of the ratings are high

# %%
unique_ratings=ratings['Book-Rating'].value_counts()
unique_ratings.sort_index()
# Out:
# 1       1770
# 2       2759
# 3       5996
# 4       8904
# 5      50974
# 6      36924
# 7      76457
# 8     103736
# 9      67541
# 10     78610
# Name: Book-Rating, dtype: int64

# %%
#percentage
(unique_ratings.sort_index()/sum(unique_ratings))*100
# Out:
# 1      0.408144
# 2      0.636197
# 3      1.382615
# 4      2.053169
# 5     11.754072
# 6      8.514288
# 7     17.630185
# 8     23.920437
# 9     15.574249
# 10    18.126644
# Name: Book-Rating, dtype: float64

# %%
ratings[ratings['ISBN']=='034545104X']
# Out:
#          User-ID        ISBN  Book-Rating
# 0         276725  034545104X            0
# 15433       2313  034545104X            5
# 27533       6543  034545104X            0
# 36088       8680  034545104X            5
# 40794      10314  034545104X            9
# 101553     23768  034545104X            0
# 122936     28266  034545104X            0
# 123655     28523  034545104X            0
# 179476     39002  034545104X            0
# 215546     50403  034545104X            9
# 243661     56157  034545104X            0
# 255428     59102  034545104X            0
# 256846     59287  034545104X            0
# 274431     63970  034545104X            8
# 325432     77480  034545104X            8
# 326772     77940  034545104X            0
# 343933     81977  034545104X            0
# 390851     94362  034545104X            5
# 407178     98391  034545104X            9
# 469774    112199  034545104X            6
# 485304    115435  034545104X            5
# 509668    123981  034545104X            0
# 530849    128045  034545104X            7
# 531617    128276  034545104X            5
# 535919    129311  034545104X            7
# 550631    132081  034545104X            0
# 553625    133235  034545104X            0
# 559785    135045  034545104X            0
# 575922    138543  034545104X            0
# 598121    144315  034545104X            0
# 598528    144486  034545104X            0
# 602125    145451  034545104X            0
# 610242    147799  034545104X            0
# 654755    158506  034545104X            0
# 670881    163202  034545104X            0
# 693259    168816  034545104X            0
# 707722    171912  034545104X            5
# 717945    173743  034545104X            0
# 723356    174834  034545104X            0
# 778339    188513  034545104X            4
# 803631    195374  034545104X            0
# 859823    208019  034545104X            0
# 861311    208406  034545104X            6
# 870270    210597  034545104X            9
# 888388    214011  034545104X           10
# 907678    220502  034545104X            3
# 936446    227106  034545104X            0
# 937748    227447  034545104X            0
# 939959    227520  034545104X            0
# 941592    227886  034545104X            3
# 999983    240144  034545104X            3
# 1015263   243142  034545104X            9
# 1019576   244420  034545104X            8
# 1069872   255502  034545104X            6
# 1076917   257492  034545104X            5
# 1088130   260897  034545104X            3
# 1096056   263003  034545104X            7
# 1117909   268191  034545104X            0
# 1131746   271448  034545104X            0
# 1143819   274925  034545104X            7
